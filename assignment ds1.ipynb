# %%
# importing package
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Reading csv data
filepath="/Users/arunmergu/Downloads/Cars_Multi.csv"

def read_csv(filepath):
    """ It will load the csv data from the given file path
    """
    cars = pd.read_csv(filepath)
    return cars

cars=read_csv(filepath)
y=cars['origin']
x=cars['cylinders']
cars
# Out:
#       ID   mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0      1  18.0          8         307.0         130    3504          12.0
# 1      2  15.0          8         350.0         165    3693          11.5
# 2      3  18.0          8         318.0         150    3436          11.0
# 3      4  16.0          8         304.0         150    3433          12.0
# 4      5  17.0          8         302.0         140    3449          10.5
# ..   ...   ...        ...           ...         ...     ...           ...
# 387  394  27.0          4         140.0          86    2790          15.6
# 388  395  44.0          4          97.0          52    2130          24.6
# 389  396  32.0          4         135.0          84    2295          11.6
# 390  397  28.0          4         120.0          79    2625          18.6
# 391  398  31.0          4         119.0          82    2720          19.4
#
#      model  origin                   car_name
# ...

# %%
#Method1
def linearplt(x,y):
    """it shows the line plot between origin and cylinder"""
    plt.plot(list(x),list(y), label='line plot between origin and cylinders')
    plt.title('')
    plt.xlabel('cylinders')
    plt.ylabel('origin')
    plt.legend(loc='upper right')
    plt.grid()
    plt.show()

linearplt(x,y)

# %%
#Method2

def histplt(data):
    """histogram of a variable in cars data"""
    plt.figure(figsize=(25, 6))
    plt.subplot(1,3,2)
    plt1 = cars.cylinders.value_counts().plot(kind='bar')
    plt.title('Number of cyliners Histogram')
    plt1.set(xlabel = 'cylinders', ylabel='Frequency of cylinders')

histplt(cars)

# %%
#Method3
def scatter(x,fig):
    
    """it shows the scatter plot between the acceleration and horsepwer"""
    plt.subplot(5,2,fig)
    plt.scatter(cars[x],cars['horsepower'])
    plt.title(x+' vs horsepower')
    plt.ylabel('horsepower')
    plt.xlabel(x)
    

plt.figure(figsize=(10,20))

scatter('acceleration', 1)
